# %%
# shift + Enter để run và add new line

# %%
# ctrl + Enter just run the code

# %%
#!pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image
from imgtools import *

# %%
dir = 'D:/anacondaPicture'

# %%
imgs = get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (923, 938)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=923x938>
# (928, 935)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=928x935>
# (923, 938)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=923x938>
# (924, 926)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=924x926>
# (922, 922)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=922x922>
# (919, 927)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=919x927>
# (922, 920)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=922x920>
