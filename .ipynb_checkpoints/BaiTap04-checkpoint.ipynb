# %%
# shift + Enter để run và add new line

# %%
# ctrl + Enter just run the code

# %%
#!pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in d:\anacondaa\lib\site-packages (10.3.0)

# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = "C:/Users/quocl/anacondaPicture/pic1.png"

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=928x935>

# %%
print(img.size)
# Out:
# (928, 935)

# %%
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x1000>

# %%
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=50x50>

# %%
image_path = dir + "/pic1.PNG"
print(image_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 image_path = dir + "/pic1.PNG"
#       2 print(image_path)
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'str'

# %%
new_pic1_path = dir + '/new_smallpic.PNG'
img.save(new_pic1_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 new_pic1_path = dir + '/new_smallpic.PNG'
#       2 img.save(new_pic1_path)
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'str'
