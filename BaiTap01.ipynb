# %%
# shift + Enter để run và add new line

# %%
# ctrl + Enter just run the code

# %%
#!pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from PIL import Image

# %%
dir = 'C:/Users/quocl/anacondaPicture'

# %%
image_path = dir + "/pic1.PNG"
print(image_path)
# Out:
# C:/Users/quocl/anacondaPicture/pic1.PNG

# %%
pic1 = Image.open(image_path)

# %%
display(pic1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=928x935>

# %%
print("Định dang ảnh: ", pic1.format)
# Out:
# Định dang ảnh:  PNG

# %%
print("Kích thước hình ảnh: ", pic1.size)
# Out:
# Kích thước hình ảnh:  (928, 935)

# %%
new_pic1_path = dir + '/new_pic11.PNG'
new_jpg_pic1_path = dir + '/new_pic12.PNG'
pic1.save(new_pic1_path)
pic1.save(new_jpg_pic1_path)

# %%
pic1.close()
