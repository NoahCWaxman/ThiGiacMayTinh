# %%
# shift + Enter để run và add new line

# %%
# ctrl + Enter just run the code

# %%
#!pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in d:\anacondaa\lib\site-packages (10.3.0)

# %%
from PIL import Image
from imgtools import *

# %%
my_path = "C:/Users/quocl/anacondaPicture/pic3.png"

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=924x926>

# %%
region = (125, 40, 225, 130)
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=100x90>

# %%
paste_position = (120, 130)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=924x926>

# %%
paste_position = (125, 260)
img.paste(cropped_image, paste_position)
display(img)
