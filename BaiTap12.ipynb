# %%
#import thu vien
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

#duong dan anh
my_path = 'C:/Users/quocl/anacondaPicture/pic8.jpg'

#doc anh
im = Image.open(my_path)

#chuyen hinh ve array
im_array = np.array(im)

#kiem tra kich thuoc cua anh
print(im_array.shape)

#chuyen doi sang anh xam
im_array_2 = np.array(im.convert('L'), 'f')
print(im_array_2.shape)
print(im_array_2.dtype)
# Out:
# (224, 224, 3)
# (224, 224)
# float32

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

#doc hinh anh tu tep
my_path = 'C:/Users/quocl/anacondaPicture/pic8.jpg'
image = Image.open(my_path)

#chuyen doi hinh anh thanh mang Numpy
image_array = np.array(image.convert('L'))

#bien doi anh xam theo yeu cau
inverted_image = 255 - image_array #Invert anh bang cach lay 255 - gia tri pixel
squared_image = image_array **2 #binh phuong gia tri pixel
clamped_image = np.clip(image_array, 100, 200) #gioi han gia tri pixel trong khoang 100 den 200

#hien thi hinh anh goc va hinh  anh da bien doi voi khoang trang 
fig, axs = plt.subplots(2, 2, figsize =(10, 10))
fig.subplots_adjust(wspace=0.2, hspace=0.2)

axs[0, 0].imshow(image_array, cmap='gray')
axs[0, 0].set_title('Hinh anh goc')

axs[0, 1].imshow(inverted_image, cmap='gray')
axs[0,1].set_title('Hinh anh da bien doi')

axs[1, 0].imshow(inverted_image, cmap='gray')
axs[1, 0].set_title('Hinh anh da bien doi')

axs[1, 1].imshow(inverted_image, cmap='gray')
axs[1,1].set_title('Hinh anh da bien doi')

plt.show()
