# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

#doc anh 
image_path = 'C:/Users/quocl/anacondaPicture/pic9.jpg'
image = Image.open(image_path)

#anh xam 
gray_image = image.convert('L')

#chuyen anh xam ve mang 
image_a = np.array(gray_image)

#tinh gradient theo huong x
gradient_x = ndimage.sobel(image_a, axis=0, mode='constant')

#hien thi anh
fig, axis = plt.subplots(2, 1, figsize=(10,8))

plt.subplot(2,1,1)
plt.imshow(gray_image, cmap='gray')
plt.title('Anh xam goc')

plt.subplot(2,1,2)
plt.imshow(gradient_x, cmap='gray')
plt.title('Anh gradient x')

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

#doc anh
image_path = 'C:/Users/quocl/anacondaPicture/pic9.jpg'
image = Image.open(image_path)

#anh xam
gray_image = image.convert('L')

#chuyen anh xam ve mang
image_a = np.array(gray_image)

#tinh gradient theo huong x
gradient_x = ndimage.sobel(image_a, axis=1, mode='constant')

#hien thi anh
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

plt.subplot(2, 1, 1)
plt.imshow(gray_image, cmap='gray')
plt.title('Anh xam goc')

plt.subplot(2, 1, 2)
plt.imshow(gradient_x, cmap='gray')
plt.title('Anh gradient x')

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

#doc anh
imgae_path = 'C:/Users/quocl/anacondaPicture/pic9.jpg'
image = Image.open(image_path)

#anh xam
gray_image = image.convert('L')

#chuyen anh xam ve mang
image_a = np.array(gray_image)

#tinh gradient theo huong x (dao ham rieng theo x) bang mat ne Prewitt x
gradient_x = ndimage.convolve(image_a, np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]]))

#tinh gradient theo huong y (dao ham rieng theo x) bang mat ne Prewitt x
gradient_y = ndimage.convolve(image_a, np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]]))

#tinh bien do gradient
gradient_magnitude = np.sqrt(gradient_x**2 + gradient_y**2)

#Hien thi anh
fig, axs = plt.subplots(2, 1, figsize = (10, 8))

plt.subplot(2, 1, 1)
plt.imshow(gray_image, cmap='gray')
plt.title('Anh xam goc')

plt.subplot(2, 1, 2)
plt.imshow(gradient_magnitude, cmap='gray')
plt.title('Anh xam goc')

plt.show()
